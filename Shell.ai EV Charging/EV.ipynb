# %% [markdown]
# # Setting the Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Demand History Dataset

# %%
dh = pd.read_csv('./src/Demand_History.csv')

# %%
dh.head()
# Out:
#    demand_point_index  x_coordinate  y_coordinate      2010      2011  \
# 0                   0           0.5           0.5  0.352242  0.667932
# 1                   1           1.5           0.5  0.325940  0.591964
# 2                   2           2.5           0.5  0.373752  0.591890
# 3                   3           3.5           0.5  0.420686  0.584055
# 4                   4           4.5           0.5  0.475621  0.647940
#
#        2012      2013      2014      2015      2016       2017       2018
# 0  0.958593  2.911901  4.338274  6.561995  8.454417  10.595324  13.119572
# 1  0.862652  2.589068  4.196034  5.745551  8.753195  11.126995  12.020091
# 2  0.969733  2.641432  3.541772  5.469161  8.414627  10.115336  14.018254
# 3  0.906547  2.378577  3.888121  5.846089  9.083868  12.424885  15.012302
# 4  0.981544  2.665400  4.218711  6.776609  8.851107  11.731131  16.355563

# %%
dh.tail()
# Out:
#       demand_point_index  x_coordinate  y_coordinate      2010      2011  \
# 4091                4091          59.5          63.5  0.171015  0.334565
# 4092                4092          60.5          63.5  0.041716  0.061741
# 4093                4093          61.5          63.5  0.100895  0.180352
# 4094                4094          62.5          63.5  0.155353  0.290825
# 4095                4095          63.5          63.5  0.209372  0.340185
#
#           2012      2013      2014      2015      2016      2017      2018
# 4091  0.556055  1.373291  1.837586  2.517146  3.352280  4.149888  5.426193
# 4092  0.131291  0.386540  0.755846  0.941116  1.107797  1.309479  2.057450
# 4093  0.296299  0.705373  1.300220  1.608609  1.822806  2.333681  3.218519
# 4094  0.557803  1.516066  2.399426  2.719197  4.494515  6.096858  6.262574
# 4095  0.749491  1.904285  2.775772  3.404641  4.574922  6.301078  6.860939

# %%
dh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4096 entries, 0 to 4095
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   demand_point_index  4096 non-null   int64
#  1   x_coordinate        4096 non-null   float64
#  2   y_coordinate        4096 non-null   float64
#  3   2010                4096 non-null   float64
#  4   2011                4096 non-null   float64
#  5   2012                4096 non-null   float64
#  6   2013                4096 non-null   float64
#  7   2014                4096 non-null   float64
#  8   2015                4096 non-null   float64
#  9   2016                4096 non-null   float64
#  10  2017                4096 non-null   float64
#  11  2018                4096 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 384.1 KB

# %%
dh.describe()
# Out:
#        demand_point_index  x_coordinate  y_coordinate         2010  \
# count          4096.00000   4096.000000   4096.000000  4096.000000
# mean           2047.50000     32.000000     32.000000     1.993306
# std            1182.55768     18.475209     18.475209     1.849883
# min               0.00000      0.500000      0.500000     0.000000
# 25%            1023.75000     16.250000     16.250000     0.474756
# 50%            2047.50000     32.000000     32.000000     1.163430
# 75%            3071.25000     47.750000     47.750000     3.665382
# max            4095.00000     63.500000     63.500000     6.641083
#
#               2011         2012         2013         2014         2015  \
# count  4096.000000  4096.000000  4096.000000  4096.000000  4096.000000
# mean      4.017967     7.552549    19.323394    31.891712    42.249471
# std       4.003144     7.658317    19.080365    31.270080    39.501338
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# ## Existing Infrastructure 2018 Dataset

# %%
ei2018 = pd.read_csv('./src/exisiting_EV_infrastructure_2018.csv')

# %%
ei2018.head()
# Out:
#    supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 0                   0     50.163110     19.412014                   23
# 1                   1     37.336451     58.119225                   27
# 2                   2     46.709232     57.525650                   31
# 3                   3     30.528626     55.379835                   26
# 4                   4     51.521781     35.116755                   32
#
#    existing_num_SCS  existing_num_FCS
# 0                 5                 3
# 1                 4                 7
# 2                 6                14
# 3                 5                 5
# 4                11                 6

# %%
ei2018.tail()
# Out:
#     supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 95                  95     45.471204     20.999414                   24
# 96                  96     30.318396     33.388335                   32
# 97                  97     36.218839     22.235766                   32
# 98                  98     42.936915     38.122442                   28
# 99                  99     19.590263      3.830284                   24
#
#     existing_num_SCS  existing_num_FCS
# 95                 3                 4
# 96                 5                10
# 97                 4                14
# 98                 7                 5
# 99                 2                11

# %%
ei2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   supply_point_index   100 non-null    int64
#  1   x_coordinate         100 non-null    float64
#  2   y_coordinate         100 non-null    float64
#  3   total_parking_slots  100 non-null    int64
#  4   existing_num_SCS     100 non-null    int64
#  5   existing_num_FCS     100 non-null    int64
# dtypes: float64(2), int64(4)
# memory usage: 4.8 KB

# %%
ei2018.describe()
# Out:
#        supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# count          100.000000    100.000000    100.000000           100.000000
# mean            49.500000     33.174596     35.901834            25.000000
# std             29.011492     15.727673     15.453024             7.020892
# min              0.000000      0.064819      1.315176             7.000000
# 25%             24.750000     22.369391     26.385616            20.750000
# 50%             49.500000     36.321027     38.621156            27.000000
# 75%             74.250000     46.988868     47.143322            30.000000
# max             99.000000     56.568010     59.787741            36.000000
#
#        existing_num_SCS  existing_num_FCS
# count        100.000000        100.000000
# mean           5.700000          6.190000
# std            2.426703          3.711013
# min            1.000000          0.000000
# 25%            4.000000          3.000000
# ...

# %% [markdown]
# # Preliminary Analysis

# %% [markdown]
# - Demand for EV Trends ()

# %% [markdown]
# # Optimization

# %%
from gekko import GEKKO

# %%
m = GEKKO()
